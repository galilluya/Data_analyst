# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#1.-Столбец-total_images" data-toc-modified-id="1.-Столбец-total_images-2.0.1"><span class="toc-item-num">2.0.1&nbsp;&nbsp;</span>1. Столбец total_images</a></span></li><li><span><a href="#2.-Столбец-last_price" data-toc-modified-id="2.-Столбец-last_price-2.0.2"><span class="toc-item-num">2.0.2&nbsp;&nbsp;</span>2. Столбец last_price</a></span></li><li><span><a href="#3.-Столбец-total_area" data-toc-modified-id="3.-Столбец-total_area-2.0.3"><span class="toc-item-num">2.0.3&nbsp;&nbsp;</span>3. Столбец total_area</a></span></li><li><span><a href="#4.-Столбец-first_day_exposition" data-toc-modified-id="4.-Столбец-first_day_exposition-2.0.4"><span class="toc-item-num">2.0.4&nbsp;&nbsp;</span>4. Столбец first_day_exposition</a></span></li><li><span><a href="#5.-Столбец-rooms" data-toc-modified-id="5.-Столбец-rooms-2.0.5"><span class="toc-item-num">2.0.5&nbsp;&nbsp;</span>5. Столбец rooms</a></span></li><li><span><a href="#6.-Столбец-celling_height" data-toc-modified-id="6.-Столбец-celling_height-2.0.6"><span class="toc-item-num">2.0.6&nbsp;&nbsp;</span>6. Столбец celling_height</a></span></li><li><span><a href="#7.-Столбец-floors_total" data-toc-modified-id="7.-Столбец-floors_total-2.0.7"><span class="toc-item-num">2.0.7&nbsp;&nbsp;</span>7. Столбец floors_total</a></span></li><li><span><a href="#8.-Столбец-living_area" data-toc-modified-id="8.-Столбец-living_area-2.0.8"><span class="toc-item-num">2.0.8&nbsp;&nbsp;</span>8. Столбец living_area</a></span></li><li><span><a href="#9.-Столбец-floor" data-toc-modified-id="9.-Столбец-floor-2.0.9"><span class="toc-item-num">2.0.9&nbsp;&nbsp;</span>9. Столбец floor</a></span></li><li><span><a href="#10.-Столбец-is_apartment" data-toc-modified-id="10.-Столбец-is_apartment-2.0.10"><span class="toc-item-num">2.0.10&nbsp;&nbsp;</span>10. Столбец is_apartment</a></span></li><li><span><a href="#11.-Столбец-studio" data-toc-modified-id="11.-Столбец-studio-2.0.11"><span class="toc-item-num">2.0.11&nbsp;&nbsp;</span>11. Столбец studio</a></span></li><li><span><a href="#12.-Столбец-open_plan" data-toc-modified-id="12.-Столбец-open_plan-2.0.12"><span class="toc-item-num">2.0.12&nbsp;&nbsp;</span>12. Столбец open_plan</a></span></li><li><span><a href="#13.-Столбец-kitchen_area" data-toc-modified-id="13.-Столбец-kitchen_area-2.0.13"><span class="toc-item-num">2.0.13&nbsp;&nbsp;</span>13. Столбец kitchen_area</a></span></li><li><span><a href="#14.-Столбец-balcony" data-toc-modified-id="14.-Столбец-balcony-2.0.14"><span class="toc-item-num">2.0.14&nbsp;&nbsp;</span>14. Столбец balcony</a></span></li><li><span><a href="#15.-Столбец-locality_name" data-toc-modified-id="15.-Столбец-locality_name-2.0.15"><span class="toc-item-num">2.0.15&nbsp;&nbsp;</span>15. Столбец locality_name</a></span></li><li><span><a href="#16.-Столбец-airports_nearest" data-toc-modified-id="16.-Столбец-airports_nearest-2.0.16"><span class="toc-item-num">2.0.16&nbsp;&nbsp;</span>16. Столбец airports_nearest</a></span></li><li><span><a href="#17.-Столбец-city_centers_nearest" data-toc-modified-id="17.-Столбец-city_centers_nearest-2.0.17"><span class="toc-item-num">2.0.17&nbsp;&nbsp;</span>17. Столбец city_centers_nearest</a></span></li><li><span><a href="#18.-Столбец-parks_around3000" data-toc-modified-id="18.-Столбец-parks_around3000-2.0.18"><span class="toc-item-num">2.0.18&nbsp;&nbsp;</span>18. Столбец parks_around3000</a></span></li><li><span><a href="#19.-Столбец-parks_nearest" data-toc-modified-id="19.-Столбец-parks_nearest-2.0.19"><span class="toc-item-num">2.0.19&nbsp;&nbsp;</span>19. Столбец parks_nearest</a></span></li><li><span><a href="#20.-Столбец-ponds_around3000" data-toc-modified-id="20.-Столбец-ponds_around3000-2.0.20"><span class="toc-item-num">2.0.20&nbsp;&nbsp;</span>20. Столбец ponds_around3000</a></span></li><li><span><a href="#21.-Столбец-ponds_nearest" data-toc-modified-id="21.-Столбец-ponds_nearest-2.0.21"><span class="toc-item-num">2.0.21&nbsp;&nbsp;</span>21. Столбец ponds_nearest</a></span></li><li><span><a href="#22.-Столбец-days_exposition" data-toc-modified-id="22.-Столбец-days_exposition-2.0.22"><span class="toc-item-num">2.0.22&nbsp;&nbsp;</span>22. Столбец days_exposition</a></span></li></ul></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В нашем распоряжении данные сервиса Яндекc Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет.
# Задача исследования — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# **Описание данных:**
# - total_images — число фотографий квартиры в объявлении
# - last_price — цена на момент снятия с публикации
# - total_area — площадь квартиры в квадратных метрах (м²)
# - first_day_exposition — дата публикации
# - rooms — число комнат
# - ceiling_height — высота потолков (м)
# - floors_total — всего этажей в доме
# - living_area — жилая площадь в квадратных метрах (м²)
# - floor — этаж
# - is_apartment — апартаменты (булев тип)
# - studio — квартира-студия (булев тип)
# - open_plan — свободная планировка (булев тип)
# - kitchen_area — площадь кухни в квадратных метрах (м²)
# - balcony — число балконов
# - locality_name — название населённого пункта
# - airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
# - cityCenters_nearest — расстояние до центра города (м)
# - parks_around3000 — число парков в радиусе 3 км
# - parks_nearest — расстояние до ближайшего парка (м)
# - ponds_around3000 — число водоёмов в радиусе 3 км
# - ponds_nearest — расстояние до ближайшего водоёма (м)
# - days_exposition — сколько дней было размещено объявление (от публикации до снятия)

# %% [markdown]
# ## Изучение данных из файла

# %%
#загружаем необходимые библиотеки
import pandas as pd
import numpy as np
import os
import re
import matplotlib.pyplot as plt
import seaborn as sb

# %%
pth1 = '/datasets/real_estate_data.csv'
pth2 = 'E:/Файлы Галя/Yandex_practicum/Datasets/real_estate_data.csv'
if os.path.exists(pth1):
    df = pd.read_csv(pth1)
elif os.path.exists(pth2):
    df = pd.read_csv(pth2)
else:
    print("Проверьте правильность пути к датасету")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 1 columns):
#  #   Column                                                                                                                                                                                                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                                                                                           --------------  -----
# ...

# %% [markdown]
# Что-то не так с данными, посмотрим первые 10 строк

# %%
df.head(10)
# Out:
#   total_images\tlast_price\ttotal_area\tfirst_day_exposition\trooms\tceiling_height\tfloors_total\tliving_area\tfloor\tis_apartment\tstudio\topen_plan\tkitchen_area\tbalcony\tlocality_name\tairports_nearest\tcityCenters_nearest\tparks_around3000\tparks_nearest\tponds_around3000\tponds_nearest\tdays_exposition
# 0  20\t13000000.0\t108.0\t2019-03-07T00:00:00\t3\...
# 1  7\t3350000.0\t40.4\t2018-12-04T00:00:00\t1\t\t...
# 2  10\t5196000.0\t56.0\t2015-08-20T00:00:00\t2\t\...
# 3  0\t64900000.0\t159.0\t2015-07-24T00:00:00\t3\t...
# 4  2\t10000000.0\t100.0\t2018-06-19T00:00:00\t2\t...
# 5  10\t2890000.0\t30.4\t2018-09-10T00:00:00\t1\t\...
# 6  6\t3700000.0\t37.3\t2017-11-02T00:00:00\t1\t\t...
# 7  5\t7915000.0\t71.6\t2019-04-18T00:00:00\t2\t\t...
# 8  20\t2900000.0\t33.16\t2018-05-23T00:00:00\t1\t...
# 9  18\t5400000.0\t61.0\t2017-02-26T00:00:00\t3\t2...

# %% [markdown]
# Данные записаны через /t, нужно разделить:

# %%
pth1 = '/datasets/real_estate_data.csv'
pth2 = 'E:/Файлы Галя/Yandex_practicum/Datasets/real_estate_data.csv'
if os.path.exists(pth1):
    df = pd.read_csv(pth1, sep='\t')
elif os.path.exists(pth2):
    df = pd.read_csv(pth2, sep='\t')
else:
    print("Проверьте правильность пути к датасету")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
df.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1             7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2            10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3             0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4             2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5            10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6             6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7             5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8            20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9            18   5400000.0       61.00  2017-02-26T00:00:00      3
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0        51.00      8          NaN  ...
# 1             NaN          11.0        18.60      1          NaN  ...
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# Из данных видим следующее:
#
# - first_day_exposition - object - должен быть тип datetime
# - ceiling_height - имеются пропуски
# - floors_total - должен быть тип int, т.к. количество этажей - целое значение, имеются пропуски
# - is_apartment - должен быть тип bool, имеются пропуски
# - living_area - имеются пропуски
# - kitchen_area - имеются пропуски
# - balcony - имеются пропуски, должен быть тип int
# - locality_name - имеются пропуски
# - airports_nearest - имеются пропуски
# - cityCenters_nearest - имеются пропуски,  нужно привести название к "змеиному" регистру
# - parks_around3000 - тип должен быть int, имеются пропуски
# - parks_nearest - имеются пропуски
# - ponds_around3000 - тип должен быть int, имеются пропуски
# - ponds_nearest - имеются пропуски
# - days_exposition - тип должен быть int, имеются пропуски
#
# Необходимо обработать пропуски и типы данных.

# %% [markdown]
# ## Предобработка данных

# %%
# выведем названия столбцов
df.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'cityCenters_nearest',
#        'parks_around3000', 'parks_nearest', 'ponds_around3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %% [markdown]
# Нужно изменить название столбца **cityCenters_nearest**.

# %%
# приводим название к "змеиному регистру"
df = df.rename(columns={'cityCenters_nearest' : 'city_centers_nearest'})

# %%
# проверка
df.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'city_centers_nearest',
#        'parks_around3000', 'parks_nearest', 'ponds_around3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %% [markdown]
# Посмотрим значения в каждом столбце отдельно:

# %% [markdown]
# ### 1. Столбец total_images

# %%
#в этом столбце со значениями все в порядке, аномалий нет
df['total_images'].value_counts()
# Out:
# 10    1798
# 9     1725
# 20    1694
# 8     1585
# 7     1521
# 6     1482
# 11    1362
# 5     1301
# 12    1225
# 0     1059
# 13    1015
# 4      986
# 14     986
# 15     948
# 1      872
# 3      769
# 16     761
# 17     650
# 18     642
# 2      640
# 19     603
# 23      16
# 21      12
# 24       8
# 22       8
# 26       5
# 32       4
# 28       4
# 50       3
# 29       3
# 27       2
# 30       2
# 35       2
# 31       2
# 42       1
# 25       1
# 39       1
# 37       1
# Name: total_images, dtype: int64

# %% [markdown]
# ### 2. Столбец last_price

# %%
#в этом столбце со значениями все в порядке, аномалий нет
df['last_price'].value_counts()
# Out:
# 4500000.0     342
# 3500000.0     291
# 4300000.0     260
# 4000000.0     260
# 4200000.0     259
#              ...
# 12890000.0      1
# 29375000.0      1
# 7545600.0       1
# 5205000.0       1
# 11475000.0      1
# Name: last_price, Length: 2978, dtype: int64

# %% [markdown]
# ### 3. Столбец total_area

# %%
#в этом столбце со значениями все в порядке, аномалий нет
df['total_area'].value_counts()
# Out:
# 45.00     419
# 42.00     383
# 60.00     347
# 31.00     346
# 44.00     345
#          ...
# 184.40      1
# 55.64       1
# 56.16       1
# 109.10      1
# 76.75       1
# Name: total_area, Length: 2182, dtype: int64

# %% [markdown]
# ### 4. Столбец first_day_exposition

# %%
#переведем столбец с датой в формат даты без времени, т.к. время не указано
df['first_day_exposition'] = pd.to_datetime(df['first_day_exposition'], format = '%Y-%m-%d')
df['first_day_exposition'].value_counts()
# Out:
# 2018-02-01    368
# 2017-11-10    240
# 2017-10-13    124
# 2017-09-27    111
# 2018-03-26     97
#              ...
# 2018-05-20      1
# 2015-05-15      1
# 2015-01-12      1
# 2015-12-19      1
# 2015-07-19      1
# Name: first_day_exposition, Length: 1491, dtype: int64

# %% [markdown]
# ### 5. Столбец rooms

# %%
#в этом столбце со значениями все в порядке, аномалий нет
df['rooms'].value_counts()
# Out:
# 1     8047
# 2     7940
# 3     5814
# 4     1180
# 5      326
# 0      197
# 6      105
# 7       59
# 8       12
# 9        8
# 10       3
# 11       2
# 14       2
# 15       1
# 19       1
# 16       1
# 12       1
# Name: rooms, dtype: int64

# %% [markdown]
# ### 6. Столбец celling_height

# %% [markdown]
# В этом столбце имеются пропуски, которые необходимо обработать, но посмотрим нет ли аномальных значений:

# %%
df['ceiling_height'].value_counts()
# Out:
# 2.50    3515
# 2.60    1646
# 2.70    1574
# 3.00    1112
# 2.80     993
#         ...
# 5.00       1
# 2.20       1
# 2.34       1
# 3.93       1
# 3.59       1
# Name: ceiling_height, Length: 183, dtype: int64

# %%
df['ceiling_height'].describe()
# Out:
# count    14504.000000
# mean         2.771499
# std          1.261056
# min          1.000000
# 25%          2.520000
# 50%          2.650000
# 75%          2.800000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Видим наличие максимального значения 100 и минимального значения 1.
#
# По запросу в Яндексе находим информацию о возможной высоте потолков в квартирах:
#
# *Если обратиться к сайтам по поиску недвижимости, то можно обнаружить большое количество жилых помещений с расстоянием от пола до перекрытия превышающим 4 метра. Но такие квартиры чаще относятся к классу «люкс» и стоят баснословных денег. Поэтому можно смело сказать, что предельная высота никак не обозначена, но согласно практике вертикальная длина стен в новых домах составляет от 2,5 до 3,2 метров.*
#
# То есть обычно высота потолков варьируется от 2,5 до 3,2 м, но может достигать и 4 м (не будем исключать такие варианты). Посмотрим на строки, содержащие значение высоты потолков выше 50 м (до 50 м мы можем предположить, что значения записаны в дм и в последующих шагах исправить это):

# %%
#посмотрим строки со значениями выше 40
df[df['ceiling_height']>40]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 22869             0  15000000.0        25.0           2018-07-25      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 22869           100.0           5.0         14.0      5         True  ...
#
#        kitchen_area  balcony    locality_name  airports_nearest  \
# 22869          11.0      5.0  Санкт-Петербург           34963.0
#
#       city_centers_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 22869               8283.0               1.0          223.0               3.0
#
#        ponds_nearest  days_exposition
# 22869           30.0             19.0
#
# [1 rows x 22 columns]

# %% [markdown]
# Всего одна строка, поэтому можем смело ее удалить (в ней в целом странные значения, поэтому грустить от ее удаления не будем):

# %%
df = df.drop(np.where(df['ceiling_height']>40.0)[0])

# %%
#проверка
df[df['ceiling_height']>40]
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, city_centers_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %%
#разделим значения высоты, превышающие 10, на 10 
df['ceiling_height'].where(~(df.ceiling_height >= 10), other=df.ceiling_height/10, inplace=True)

# %%
#проверка
df[df['ceiling_height']>=10]
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, city_centers_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# Все большие значения перевели в метры. (Я намеренно сделала это раньше удаления низких значений, так как некоторые большие значения после деления превращаются в малые и они в этапе удаления тоже попадут под условие.)

# %% [markdown]
# Теперь посмотрим строки, содержащие значения ниже 2,4 м (в некоторых квартирах могут быть натяжные потолки, которые уменьшают высоту потолков, примем это изменение высоты за 10 см, поэтому нижняя граница потолков становится 2,4 м):

# %%
df[df['ceiling_height']<2.4]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 227              13   2200000.0       47.00           2018-01-12      3
# 552              11   2999000.0       33.50           2017-03-30      1
# 1582              4   4100000.0       45.60           2016-01-13      2
# 2572              4   2400000.0       62.00           2018-12-27      3
# 4212              1   2120000.0       35.43           2017-12-18      1
# 5498             17   2200000.0       56.00           2018-04-02      2
# 5712              5   1500000.0       42.80           2017-08-14      2
# 5850              9   1650000.0       35.50           2018-05-29      1
# 11352             4   3300000.0       36.00           2017-06-18      1
# 12755             2   1400000.0       22.50           2017-09-21      1
# 15061            19   5600000.0       56.40           2018-05-11      2
# 16446             6  12300000.0       88.30           2019-03-12      3
# ...

# %% [markdown]
# Таких строк немного, поэтому можем их безжалостно удалить, предполгая, то это какие-то подвальные помещения, это не сильно повлияет на дальнейший анализ.

# %%
#удалим строки с помощью цикла
delete = df[df['ceiling_height']<2.4].index
drop_index=0
try:
    for drop_str in delete:
        df = df.drop(drop_str)
        drop_index+=1
except:
    print('Не удалось удалить строку')
print("Удалено строк: ", drop_index)
print("Всего осталось строк:", len(df))
# Out:
# Удалено строк:  25
# Всего осталось строк: 23673

# %%
#проверка
df[df['ceiling_height']<2.4]
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, city_centers_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %%
df = df.reset_index(drop=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23673 entries, 0 to 23672
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23673 non-null  int64
#  1   last_price            23673 non-null  float64
#  2   total_area            23673 non-null  float64
#  3   first_day_exposition  23673 non-null  datetime64[ns]
#  4   rooms                 23673 non-null  int64
#  5   ceiling_height        14478 non-null  float64
#  6   floors_total          23587 non-null  float64
#  7   living_area           21773 non-null  float64
#  8   floor                 23673 non-null  int64
#  9   is_apartment          2770 non-null   object
#  10  studio                23673 non-null  bool
#  11  open_plan             23673 non-null  bool
#  12  kitchen_area          21399 non-null  float64
#  13  balcony               12166 non-null  float64
# ...

# %% [markdown]
# Осталось 23673 строк с данными.

# %% [markdown]
# Теперь обработаем значения выше 4 м (более 10 метров мы уже разделили на 10, поэтому теперь высокие значения располагаются в пределах от 4 до 10, так как больше 10 уже нет значений)

# %%
df[df['ceiling_height']>4]
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 154               1    8200000.0        80.0           2018-11-06      3
# 463              15   66571000.0       280.3           2015-06-11      6
# 1024             20  155000000.0       310.0           2018-10-12      5
# 1051             13     550000.0        29.0           2018-02-01      1
# 1127             20    6695000.0        36.9           2018-09-28      1
# 1298             14  120000000.0       280.0           2018-07-12      5
# 1386             20   59800000.0       399.0           2015-01-21      5
# 2635             17    4850000.0        59.7           2017-11-18      3
# 2798              7   14950000.0        50.0           2016-03-06      2
# 2819              8    2700000.0        39.0           2018-02-01      1
# 2839             15   11990000.0       104.0           2018-03-13      3
# 2995             11    4450000.0        36.0           2017-12-12      1
# ...

# %% [markdown]
# Таких строк обнаружилось 50. Видно, что есть значения 4,15 или 4,20, то есть достаточно похожие на правду, а есть и 8.
#
# Поступим так: значения потолков выше 4 метров (берем это значение, так как при поиске в Яндексе обнаружилось, что на сайтах недвижимости имеется достаточно большое количество предложений, имеющих высоту потолков более 4 м) приведем к среднему значению высоты потолков (не беря в расчет пропуски, естесственно), а пропущенные значения тоже заполним средним значением высоты потолков.

# %%
#медианная высота потолков (исключая строки с пропущенными значениями)
is_height = df.loc[df['ceiling_height'].isna()==False]
median_ceiling = is_height['ceiling_height'].dropna().median()
print("Медианное значение высоты потолков =", median_ceiling)
# Out:
# Медианное значение высоты потолков = 2.65

# %%
#меняем значения высоты потолков
df.loc[(df['ceiling_height'].isna()==False) & (df['ceiling_height']>4), 'ceiling_height'] = median_ceiling

# %%
#заполняем пропуски с округлением до десятых
df['ceiling_height'] = df['ceiling_height'].fillna(median_ceiling).round(2)

# %%
#проверка
df.loc[(df['ceiling_height'].isna()==False) & (df['ceiling_height']>4)]
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, city_centers_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %%
#Проверим наличие пропусков
df['ceiling_height'].isna().sum()
# Out:
# 0

# %%
#проверим инфоормацию по данному столбцу
df['ceiling_height'].describe()
# Out:
# count    23673.000000
# mean         2.693688
# std          0.203878
# min          2.400000
# 25%          2.600000
# 50%          2.650000
# 75%          2.700000
# max          4.000000
# Name: ceiling_height, dtype: float64

# %%
#и посмотрим информацию по всему датафрейму
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23673 entries, 0 to 23672
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23673 non-null  int64
#  1   last_price            23673 non-null  float64
#  2   total_area            23673 non-null  float64
#  3   first_day_exposition  23673 non-null  datetime64[ns]
#  4   rooms                 23673 non-null  int64
#  5   ceiling_height        23673 non-null  float64
#  6   floors_total          23587 non-null  float64
#  7   living_area           21773 non-null  float64
#  8   floor                 23673 non-null  int64
#  9   is_apartment          2770 non-null   object
#  10  studio                23673 non-null  bool
#  11  open_plan             23673 non-null  bool
#  12  kitchen_area          21399 non-null  float64
#  13  balcony               12166 non-null  float64
# ...

# %% [markdown]
# Теперь в этом столбце все в порядке.

# %% [markdown]
# ### 7. Столбец floors_total

# %%
#в этом столбце имеются нулевые значения, их всего 86 (0,36%) от общего числа, поэтому можем удалить их
df['floors_total'].isna().sum()
# Out:
# 86

# %%
df = df.drop(np.where(df['floors_total'].isna() == True)[0])

# %%
df['floors_total'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### 8. Столбец living_area

# %% [markdown]
# Нужно заполнить пропуски в столбце **living_area**
# Обычно общая площадь квартиры = жилая + нежилая. Балкон и лоджия в общую площадь квартиры не входят.
#
# Сначала рассмотрим квартиры-студии, так как этот тип квартир отличается рассчетом общей площади.

# %%
print("Студий всего:", len(df.loc[df['studio']==True]))
print("Студий с заполненными значениями:", df.loc[df['studio']==True, 'living_area'].describe().round(2))
df['studio'].value_counts()
# Out:
# Студий всего: 146
# Студий с заполненными значениями: count    139.00
# mean      19.00
# std        7.35
# min        2.00
# 25%       16.00
# 50%       18.00
# 75%       19.85
# max       68.00
# Name: living_area, dtype: float64
# False    23441
# True       146
# Name: studio, dtype: int64

# %% [markdown]
# Присутствуют слишком маленькие жилые площади min=2. Скорее всего это произошло, потому что не был дописан 0 или не написаны десятки.
#
# Если изучить законодательство Российской Федерации, то, к примеру, в Москве согласно закону № 29 об обеспечении жильём гражданских лиц установлены следующие размеры:
# - минимальной площадью на одного человека является 10 м² (либо 15 м² по суду).
# - однокомнатная квартира для семьи из двух человек – 44 м²
# - двухкомнатная для двух граждан, если их брак официально не зарегистрирован, – 54 м²
# - двухкомнатная квартира для семьи из трёх человек— 62 м²
# - трёхкомнатная для трёх несемейных граждан — 74 м²
#
# Посмотрим на строки, которые содержат аномальные значения:

# %%
df[(df['living_area']<10) & (df['studio']==True)]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 17567            11   2680000.0        22.0           2018-08-11      0
# 21737             0   2330000.0        23.0           2018-01-01      0
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 17567            2.65          25.0          5.0      8          NaN  ...
# 21737            2.65          24.0          2.0     22          NaN  ...
#
#        kitchen_area  balcony    locality_name  airports_nearest  \
# 17567           NaN      2.0  Санкт-Петербург           22735.0
# 21737           NaN      NaN   посёлок Мурино               NaN
#
#       city_centers_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 17567              11618.0               1.0          835.0               1.0
# 21737                  NaN               NaN            NaN               NaN
#
#        ponds_nearest  days_exposition
# 17567          652.0             70.0
# ...

# %% [markdown]
# Всего две строки и это хорошо, так как изменение большого числа строк могло привести к бОльшему искажению результатов.
# Целесообразно **прибавить 10** к значениям **living_area**, так как общая площадь составляет 22 и 23 квадратных метра. При умножении на 10 площадь жилых помещений превысит общую площадь, поэтому этого делать не будем.

# %%
replace_list = df.loc[(df['living_area']<10) & (df['studio']==True), ['living_area', 'total_area']].index
print(df.loc[replace_list, ['living_area', 'total_area']])
print()
df.loc[(df['living_area']<10) & (df['studio']==True), 'living_area'] +=10
print(df.loc[replace_list, ['living_area', 'total_area']])
# Out:
#        living_area  total_area
# 17567          5.0        22.0
# 21737          2.0        23.0
#
#        living_area  total_area
# 17567         15.0        22.0
# 21737         12.0        23.0

# %% [markdown]
# Оставшиеся пропуски обработаем таким образом: найдем среднюю долю жилой площади от общей площади студии и заполним пропуски произведением общей площади квартиры-студии (тем более что в столбце **total_area** нет пропусков) и найденного среднего значения доли.

# %%
print("Кол-во строк с данными площади жилых помещений студий:", df.loc[(df['living_area'].isna() == False) & (df['studio']==True), 
        'living_area'].count(), " | Кол-во строк студий всего:", df.loc[df['studio']==True, 'total_area'].count())
proportion = df.loc[df['studio']==True, 'living_area'] / df.loc[df['studio']==True, 'total_area']

#средняя доля жилой площади в студиях без учета строк с пропущенными значениями
print("Средняя доля жилой площади в студии =", proportion.dropna().mean())

#меняем значение жилой площади в студии на = доля*общую
df.loc[(df['living_area'].isna() == True) & (df['studio']==True), 'living_area'] = df.loc[(df['living_area'].isna() == True) 
    & (df['studio']==True), 'total_area'] * proportion.dropna().mean()
# Out:
# Кол-во строк с данными площади жилых помещений студий: 139  | Кол-во строк студий всего: 146
# Средняя доля жилой площади в студии = 0.6879269478769845

# %%
#проверим
print("Кол-во строк с данными площади жилых помещений студий:", df.loc[(df['living_area'].isna() == False) & (df['studio']==True), 
        'living_area'].count(), " | Кол-во строк студий всего:", df.loc[df['studio']==True, 'total_area'].count())

df.query('studio==True')
# Out:
# Кол-во строк с данными площади жилых помещений студий: 146  | Кол-во строк студий всего: 146
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 144               1   2450000.0       27.00           2017-03-30      0
# 439               8   2480000.0       27.11           2018-03-12      0
# 606               2   1850000.0       25.00           2019-02-20      0
# 695              12   2500000.0       24.10           2017-12-01      0
# 714               5   1500000.0       17.00           2017-06-07      0
# ...             ...         ...         ...                  ...    ...
# 22844             8   3090000.0       30.00           2017-12-17      0
# 22853             2   4280000.0       28.00           2017-10-26      0
# 23185             7   3200000.0       26.00           2017-09-01      0
# 23528            15   3350000.0       26.00           2018-09-07      0
# 23611             8   2350000.0       26.00           2018-06-26      0
#
# ...

# %% [markdown]
# Со студиями разобрались, теперь перейдем к остальным квартирам.
#
# Сделаем аналогичным методом: найдем отношение жилой площади к общей площади квартиры и заполним пропуски в столбце **living_area** для квартир не студий произведением общей площади квартиры и найденного среднего значения доли:

# %%
print("Кол-во строк с данными жилой площади квартир не студий:", df.loc[(df['living_area'].isna() == False) & (df['studio']==False), 
        'living_area'].count(), " | Кол-во строк квартир не студий всего:", df.loc[df['studio']==False, 'total_area'].count())
proportion = df.loc[df['studio']==False, 'living_area'] / df.loc[df['studio']==False, 'total_area']

# Средняя доля жилой в студиях без учета строк с пропущенными значениями
print("Средняя доля жилой площади в студии =", proportion.dropna().mean())

# Меняем значение жилой в студии на = доля*общую
df.loc[(df['living_area'].isna() == True) & (df['studio']==False), 'living_area'] = df.loc[(df['living_area'].isna() == True) 
    & (df['studio']==False), 'total_area'] * proportion.dropna().mean()
# Out:
# Кол-во строк с данными жилой площади квартир не студий: 21581  | Кол-во строк квартир не студий всего: 23441
# Средняя доля жилой площади в студии = 0.564170451530237

# %%
#проверим
print("Кол-во строк с данными жилой площади квартир не студий:", df.loc[(df['living_area'].isna() == False) & (df['studio']==False), 
        'living_area'].count(), " | Кол-во строк квартир не студий всего:", df.loc[df['studio']==False, 'total_area'].count())
df.query('studio==False')
# Out:
# Кол-во строк с данными жилой площади квартир не студий: 23441  | Кол-во строк квартир не студий всего: 23441
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00           2019-03-07      3
# 1                 7   3350000.0       40.40           2018-12-04      1
# 2                10   5196000.0       56.00           2015-08-20      2
# 3                 0  64900000.0      159.00           2015-07-24      3
# 4                 2  10000000.0      100.00           2018-06-19      2
# ...             ...         ...         ...                  ...    ...
# 23668             9   9700000.0      133.81           2017-03-21      3
# 23669            14   3100000.0       59.00           2018-01-15      3
# 23670            18   2500000.0       56.70           2018-02-11      2
# 23671            13  11475000.0       76.75           2017-03-28      2
# ...

# %% [markdown]
# Округлим значения в столбце **living_area** до сотых для наглядности (сложно воспринимать цифры с большим количеством цифр после запятой)

# %%
df['living_area'] = df['living_area'].round(2)
df.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00           2019-03-07      3
# 1             7   3350000.0       40.40           2018-12-04      1
# 2            10   5196000.0       56.00           2015-08-20      2
# 3             0  64900000.0      159.00           2015-07-24      3
# 4             2  10000000.0      100.00           2018-06-19      2
# 5            10   2890000.0       30.40           2018-09-10      1
# 6             6   3700000.0       37.30           2017-11-02      1
# 7             5   7915000.0       71.60           2019-04-18      2
# 8            20   2900000.0       33.16           2018-05-23      1
# 9            18   5400000.0       61.00           2017-02-26      3
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0        51.00      8          NaN  ...
# 1            2.65          11.0        18.60      1          NaN  ...
# ...

# %%
#проверим, остались ли пропуски в столбце living_area 
df['living_area'].isna().sum()
# Out:
# 0

# %%
#поменяем тип значений в этом столбце на int
df['living_area'].astype('int')
# Out:
# 0        51
# 1        18
# 2        34
# 3        89
# 4        32
#          ..
# 23668    73
# 23669    38
# 23670    29
# 23671    43
# 23672    12
# Name: living_area, Length: 23587, dtype: int32

# %% [markdown]
# Пропуски в этом столбце заполнили, теперь все в порядке

# %% [markdown]
# ### 9. Столбец floor

# %%
#в этом столбце со значениями все в порядке, аномалий нет
df['floor'].value_counts()
# Out:
# 2     3363
# 3     3068
# 1     2908
# 4     2793
# 5     2612
# 6     1295
# 7     1213
# 8     1073
# 9     1044
# 10     684
# 12     519
# 11     519
# 13     376
# 15     339
# 14     334
# 16     315
# 17     226
# 18     175
# 19     144
# 21     121
# 22     112
# 20     108
# 23      99
# 24      61
# 25      46
# 26      24
# 27      10
# 28       1
# 30       1
# 29       1
# 32       1
# 33       1
# 31       1
# Name: floor, dtype: int64

# %% [markdown]
# ### 10. Столбец is_apartment

# %%
#исправим тип данных на bool
df['is_apartment'] = df['is_apartment'].astype('bool')
df['is_apartment'].value_counts()
# Out:
# True     20866
# False     2721
# Name: is_apartment, dtype: int64

# %%
#проверка
df['is_apartment'].dtype
# Out:
# dtype('bool')

# %% [markdown]
# Если в столбце is_apartment есть пропуски, то возможно это из-за того, что этот столбец не заполняли в том случае, если в этом не было необходимости (то есть в том случае, если это не апартаменты), поэтому заполним пропуски значениями **False**

# %%
#заполним пропуски 
df['is_apartment'] = df['is_apartment'].fillna('False')

# %%
#проверка
df['is_apartment'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### 11. Столбец studio

# %%
#в этом столбце со значениями все в порядке, аномалий нет
df['studio'].value_counts()
# Out:
# False    23441
# True       146
# Name: studio, dtype: int64

# %% [markdown]
# ### 12. Столбец open_plan

# %%
#в этом столбце со значениями все в порядке, аномалий нет
df['open_plan'].value_counts()
# Out:
# False    23520
# True        67
# Name: open_plan, dtype: int64

# %% [markdown]
# ### 13. Столбец kitchen_area

# %%
#в этом столбце имеются пропуски
df['kitchen_area'].isna().sum()
# Out:
# 139

# %%
df['kitchen_area'].describe()
# Out:
# count    21360.000000
# mean        10.566551
# std          5.906223
# min          1.300000
# 25%          7.000000
# 50%          9.100000
# 75%         12.000000
# max        112.000000
# Name: kitchen_area, dtype: float64

# %% [markdown]
# Видим значение довольно большое (112 квадратных метров), посмотрим эти строки (в принципе такая кухня может и бывает, но все же нужно проверить).

# %%
df[df['kitchen_area']==112]
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 19521             8  420000000.0       900.0           2017-12-06     12
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 19521             2.8          25.0        409.7     25          True  ...
#
#        kitchen_area  balcony    locality_name  airports_nearest  \
# 19521         112.0      NaN  Санкт-Петербург           30706.0
#
#       city_centers_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 19521               7877.0               0.0            NaN               2.0
#
#        ponds_nearest  days_exposition
# 19521          318.0            106.0
#
# [1 rows x 22 columns]

# %% [markdown]
# Похоже на правду, так как общая площадь 900 квадратных метров, поэтому оставим все как есть.
#
# Так же, как и в случае с **living_area**, заполним пропуски значениями в зависимости от типа квартиры (студия или нет).

# %%
print("Студий всего:", len(df.loc[df['studio']==True]))
print("Студий с заполненными значениями:", df.loc[df['studio']==True, 'kitchen_area'].describe().round(2))
# Out:
# Студий всего: 146
# Студий с заполненными значениями: count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: kitchen_area, dtype: float64

# %% [markdown]
# Получается, все студии имеют пропуски в значениях столбца **kitchen_area**, это логично, так как в студиях нет отдельного помещения для кухни. Поэтому просто заполним пропуски в студиях нулями.

# %%
kitchen_studio = df.loc[(df['studio']==True), 'kitchen_area']
kitchen_studio = kitchen_studio.fillna('0')

# %%
#проверка
kitchen_studio
# Out:
# 144      0
# 439      0
# 606      0
# 695      0
# 714      0
#         ..
# 22844    0
# 22853    0
# 23185    0
# 23528    0
# 23611    0
# Name: kitchen_area, Length: 146, dtype: object

# %% [markdown]
# Со студиями разобрались, теперь перейдем к остальным квартирам.
#
# Найдем отношение площади кухни к нежилой площади  и заполним пропуски в столбце **kitchen_area** для квартир не студий произведением найденного соотношения и нежилой площади:

# %%
kitchen_not_studio = df.loc[(df['studio']==False), 'kitchen_area']
kitchen_not_studio
# Out:
# 0        25.00
# 1        11.00
# 2         8.30
# 3          NaN
# 4        41.00
#          ...
# 23668    13.83
# 23669     8.50
# 23670      NaN
# 23671    23.30
# 23672     9.00
# Name: kitchen_area, Length: 23441, dtype: float64

# %%
not_studio = df['studio']==False
kitchen_gaps = df['kitchen_area'].isna() == True
kitchen_data = df['kitchen_area'].isna() == False

print("Кол-во строк с данными жилой площади квартир не студий:", df.loc[kitchen_data & not_studio, 
        'kitchen_area'].count(), " | Кол-во строк квартир не студий всего:", df.loc[not_studio, 'total_area'].count())

#добавим столбец с данными нежилой площади
df['non-living_area'] = df['total_area'] - df['living_area']

#найдем соотношение площади кухни к нежилой площади в квартирах не студиях
proportion_two = df.loc[not_studio, 'kitchen_area'] / df.loc[not_studio, 'non-living_area']

#средняя доля кухни в квартирах не студиях
print("Средняя доля площади кухни от нежилой площади не в студиях =", proportion_two.dropna().mean())

#заполняем пропуски 
df.loc[kitchen_gaps & not_studio, 'kitchen_area'] = df.loc[kitchen_gaps & not_studio, 'non-living_area'] * proportion_two.dropna().mean()
# Out:
# Кол-во строк с данными жилой площади квартир не студий: 23129  | Кол-во строк квартир не студий всего: 23129
# Средняя доля площади кухни от нежилой площади не в студиях = 0.43084314596897855

# %%
#проверим
print("Кол-во строк с данными жилой площади квартир не студий:", df.loc[kitchen_data & not_studio, 
        'kitchen_area'].count(), " | Кол-во строк квартир не студий всего:", df.loc[not_studio, 'total_area'].count())
df.query('studio==False')
# Out:
# Кол-во строк с данными жилой площади квартир не студий: 23129  | Кол-во строк квартир не студий всего: 23129
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0              20.0  13000000.0      108.00           2019-03-07    3.0
# 1               7.0   3350000.0       40.40           2018-12-04    1.0
# 2              10.0   5196000.0       56.00           2015-08-20    2.0
# 3               0.0  64900000.0      159.00           2015-07-24    3.0
# 4               2.0  10000000.0      100.00           2018-06-19    2.0
# ...             ...         ...         ...                  ...    ...
# 23534           9.0   9700000.0      133.81           2017-03-21    3.0
# 23535          14.0   3100000.0       59.00           2018-01-15    3.0
# 23536          18.0   2500000.0       56.70           2018-02-11    2.0
# 23537          13.0  11475000.0       76.75           2017-03-28    2.0
# ...

# %%
#проверка пропусков
df['kitchen_area'].isna().sum()
# Out:
# 139

# %% [markdown]
# Это остались наши 0 после заполнения пропусков для квартир-студий, поэтому тут все в порядке.

# %% [markdown]
# ### 14. Столбец balcony

# %%
df['balcony'].value_counts()
# Out:
# 1.0    4189
# 0.0    3711
# 2.0    3653
# 5.0     302
# 4.0     183
# 3.0      81
# Name: balcony, dtype: int64

# %%
#в этом столбце имеются пропуски, проверим их количество
df['balcony'].isna().sum()
# Out:
# 11468

# %% [markdown]
# Посмотрим несколько строк, содержащих пропуски (логично предположить, что если есть пропуск, то балкона нет, но пропусков достаточное количество, поэтому стоит проверить)

# %%
df[df['balcony'].isna()==True].head(10)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20  13000000.0      108.00           2019-03-07      3
# 4              2  10000000.0      100.00           2018-06-19      2
# 5             10   2890000.0       30.40           2018-09-10      1
# 8             20   2900000.0       33.16           2018-05-23      1
# 10             5   5050000.0       39.60           2017-11-16      1
# 16            11   6700000.0       82.00           2017-11-23      3
# 19            16  14200000.0      121.00           2019-01-09      3
# 23            11   2950000.0       32.00           2016-10-29      1
# 26             6   4050000.0       60.00           2017-04-28      4
# 30            12   2200000.0       32.80           2018-02-19      1
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0             2.70          16.0        51.00      8          True  ...
# ...

# %% [markdown]
# Скорее всего либо нет балкона, либо имеется лоджия или терраса, которые не входят в понятие "балкон". Поэтому заменим все пропуски на 0.

# %%
df['balcony'] = df['balcony'].fillna(0)

# %%
#проверка
df['balcony'].isna().sum()
# Out:
# 0

# %%
#Нужно поменять тип данных на int, так как количество балконов не может быть дробным числом
df['balcony'] = df['balcony'].astype('int')

# %% [markdown]
# ### 15. Столбец locality_name

# %%
#проверим наличие дубликатов в этом столбце
df['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'посёлок Шушары', 'городской посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина', 'поселок Мурино',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Лебяжье',
#        'посёлок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'посёлок Аннино',
#        'поселок городского типа Ефимовский', 'посёлок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
# ...

# %% [markdown]
# Имеются дубликаты **поселок** и **посёлок** и дубликаты **поселок городского типа** и **городской поселок**

# %%
#Заменим все "ё" на "е"
count = 0 # счетчик строк с ё
for index in df.loc[(df['locality_name'].isna()==False),'locality_name'].index:    
    value = df.loc[index, 'locality_name']
    if 'ё' in value:
        count+=1
        value = re.sub('ё', 'е', value)
    df.loc[index, 'locality_name'] = value
print()
print("Кол-во измененных строк:", count)
# Out:
# Кол-во измененных строк: 2136

# %%
#Заменим все "городской поселок" на "поселок городского типа"
count = 0 # счетчик строк
for index in df.loc[(df['locality_name'].isna()==False),'locality_name'].index:    
    value = df.loc[index, 'locality_name']
    if 'городской поселок' in value:
        count+=1
        value = re.sub('городской поселок', 'поселок городского типа', value)
    df.loc[index, 'locality_name'] = value
print()
print("Кол-во измененных строк:", count)
# Out:
# Кол-во измененных строк: 185

# %%
df['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'поселок Шушары',
#        'поселок городского типа Янино-1', 'поселок Парголово',
#        'поселок Мурино', 'Ломоносов', 'Сертолово', 'Петергоф', 'Пушкин',
#        'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина',
#        'деревня Федоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'поселок Металлострой',
#        'поселок городского типа Лебяжье',
#        'поселок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'поселок Аннино',
#        'поселок городского типа Ефимовский', 'поселок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
#        'Красное Село', 'поселок Понтонный', 'Сясьстрой', 'деревня Старая',
# ...

# %%
#также в этом столбце имеются пропуски
df['locality_name'].isna().sum()
# Out:
# 48

# %%
#посмотрим на эти строки
df[df['locality_name'].isna()==True]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 1095              3   8600000.0       81.70           2016-04-15      3
# 2030              6   5398000.0       80.00           2017-05-30      3
# 2599             20   3351765.0       42.70           2015-09-20      1
# 2628              2   5130593.0       62.40           2015-10-11      2
# 3570             10   4200000.0       46.50           2016-05-28      2
# 4147             17  17600000.0       89.50           2014-12-09      2
# 4185              7   9200000.0       80.00           2015-12-10      3
# 4665              1   5500000.0       83.00           2015-08-14      3
# 5338             19  13540000.0       85.50           2016-01-20      3
# 5701              7   3700000.0       30.00           2016-04-29      1
# 6757             20   4895892.0       60.70           2015-03-12      2
# 7106              5   4250000.0       56.00           2016-03-16      3
# ...

# %% [markdown]
# Название населенного пункта вычислить будет сложно, поэтому удалим эти строки.

# %%
df = df.dropna(subset=['locality_name'])

# %%
#проверка
df['locality_name'].isna().sum()
# Out:
# 0

# %%
df = df.reset_index(drop=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23539 entries, 0 to 23538
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23539 non-null  int64
#  1   last_price            23539 non-null  float64
#  2   total_area            23539 non-null  float64
#  3   first_day_exposition  23539 non-null  datetime64[ns]
#  4   rooms                 23539 non-null  int64
#  5   ceiling_height        23539 non-null  float64
#  6   floors_total          23539 non-null  float64
#  7   living_area           23539 non-null  float64
#  8   floor                 23539 non-null  int64
#  9   is_apartment          23539 non-null  bool
#  10  studio                23539 non-null  bool
#  11  open_plan             23539 non-null  bool
#  12  kitchen_area          23393 non-null  float64
#  13  balcony               23539 non-null  int32
# ...

# %% [markdown]
# С этим столбцом теперь все в порядке, идем дальше.

# %% [markdown]
# ### 16. Столбец airports_nearest

# %%
df['airports_nearest'].isna().sum()
# Out:
# 5509

# %%
df['airports_nearest'].describe()
# Out:
# count    18030.000000
# mean     28796.457238
# std      12633.904313
# min          0.000000
# 25%      18559.000000
# 50%      26755.500000
# 75%      37273.000000
# max      84869.000000
# Name: airports_nearest, dtype: float64

# %% [markdown]
# Видим, что имеются нулевые значения, посмотрим эти строки:

# %%
df[df['airports_nearest']==0]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 20947             0   7000000.0        34.7           2018-09-23      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 20947             2.7           9.0         19.8      3          True  ...
#
#        balcony    locality_name  airports_nearest  city_centers_nearest  \
# 20947        2  Санкт-Петербург               0.0               22801.0
#
#       parks_around3000  parks_nearest  ponds_around3000  ponds_nearest  \
# 20947              0.0            NaN               0.0            NaN
#
#        days_exposition  non-living_area
# 20947             60.0             14.9
#
# [1 rows x 23 columns]

# %% [markdown]
# Всего одна строка, можем заменить 0 на NaN, чтобы обработать с остальными пропусками.

# %%
df.loc[(df['airports_nearest']==0)] = np.NaN

# %%
#проверка
df[df['airports_nearest']==0]
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, city_centers_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition, non-living_area]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# Заменим пропуски на медианные значения по каждому населенному пункту:

# %%
print('Медианы airports_nearest в каждом населенном пункте: ')
airports_median = df.groupby('locality_name')['airports_nearest'].median().sort_values()
airports_median = airports_median.dropna()
airports_median
# Out:
# Медианы airports_nearest в каждом населенном пункте:
# locality_name
# поселок Александровская    12896.5
# Пушкин                     15766.0
# поселок Шушары             17427.0
# Павловск                   20529.5
# поселок Петро-Славянка     20605.0
# Красное Село               25723.5
# поселок Металлострой       25758.0
# Колпино                    26232.0
# поселок Усть-Ижора         26510.5
# Санкт-Петербург            26757.5
# поселок Стрельна           28317.0
# поселок Понтонный          30642.0
# поселок Саперный           34147.5
# Петергоф                   39231.0
# Ломоносов                  48415.5
# поселок Левашово           52693.0
# поселок Парголово          53426.0
# поселок Песочный           54831.5
# поселок Лисий Нос          55909.0
# Сестрорецк                 56692.0
# поселок Белоостров         57769.0
# поселок Репино             61797.5
# Кронштадт                  67850.0
# Зеленогорск                72282.0
# поселок Молодежное         84665.0
# ...

# %%
def median_airports(name):
    if name not in airports_median:
        return np.nan
    return airports_median[name]
df.loc[df['airports_nearest'].isna()==True, 'airports_nearest'] = df['locality_name'].apply(median_airports)

# %%
#проверка
df['airports_nearest'].isna().sum()
# Out:
# 5418

# %% [markdown]
# Остальное заполним медианным значением по всему столбцу

# %%
#медиана 
median_airports = df['airports_nearest'].dropna().median()
median_airports
# Out:
# 26757.5

# %%
#заполняем пропуски 
df['airports_nearest'] = df['airports_nearest'].fillna(median_airports)

# %%
#проверка
df['airports_nearest'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### 17. Столбец city_centers_nearest

# %%
#в столбце имеются пропуски
df['city_centers_nearest'].isna().sum()
# Out:
# 5487

# %% [markdown]
# Здесь не будем заполнять пропуски, так как для каждого населенного пункта нужно будет это делать отдельно, целесообрзанее их оставить. Заполнять нулями тоже не будем, так как это может повлиять на дальнейший анализ.

# %% [markdown]
# ### 18. Столбец parks_around3000

# %%
# В столбце имеются пропуски
df['parks_around3000'].isna().sum()
# Out:
# 5486

# %%
df['parks_around3000'].value_counts()
# Out:
# 0.0    10034
# 1.0     5642
# 2.0     1734
# 3.0      643
# Name: parks_around3000, dtype: int64

# %% [markdown]
# Количество парков не повлияет на анализ, поэтому заполним пропуски нулями:

# %%
df['parks_around3000'] = df['parks_around3000'].fillna(0)

# %%
#проверка
df['parks_around3000'].isna().sum()
# Out:
# 0

# %% [markdown]
# Заменим тип данных на int, так как количество парков не может быть дробным числом

# %%
df['parks_around3000'] = df['parks_around3000'].astype('int')

# %%
#проверка
df['parks_around3000'].dtype
# Out:
# dtype('int32')

# %% [markdown]
# ### 19. Столбец parks_nearest

# %%
# В столбце имеются пропуски
df['parks_nearest'].isna().sum()
# Out:
# 15516

# %% [markdown]
# Оставим эти пропуски, они не повлияют на дальнейший анализ.

# %% [markdown]
# ### 20. Столбец ponds_around3000

# %%
# В столбце имеются пропуски
df['ponds_around3000'].isna().sum()
# Out:
# 5486

# %% [markdown]
# Количество водоемов не повлияет на анализ, поэтому заполним пропуски 0.

# %%
df['ponds_around3000'] = df['ponds_around3000'].fillna(0)

# %%
#проверка
df['ponds_around3000'].isna().sum()
# Out:
# 0

# %% [markdown]
# Заменим тип данных на int, так как количество парков не может быть дробным числом

# %%
df['ponds_around3000'] = df['ponds_around3000'].astype('int')

# %%
#проверка
df['ponds_around3000'].dtype
# Out:
# dtype('int32')

# %% [markdown]
# ### 21. Столбец ponds_nearest

# %%
# В столбце имеются пропуски
df['ponds_nearest'].isna().sum()
# Out:
# 14510

# %% [markdown]
# Оставим эти пропуски, они не повлияют на дальнейший анализ.

# %% [markdown]
# ### 22. Столбец days_exposition

# %%
# В столбце имеются пропуски
df['days_exposition'].isna().sum()
# Out:
# 3168

# %% [markdown]
# Возможно пропуски появились так как квартира еще не продана, поэтому заполним их нулями, предполагая, что квартира еще продается.

# %%
#заполним пропуски 0 и заменим тип данных на int
df['days_exposition'] = df['days_exposition'].fillna(0).astype('int')

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %%
#добавляем стоимость квадратного метра
df['price_per_square_meter'] = (df['last_price'] / df['total_area']).round(2)

# %%
#новый столбец для дня недели
df['weekday_exposition'] = df['first_day_exposition'].dt.weekday

# %%
#новый столбец для месяца
df['month_exposition'] = df['first_day_exposition'].dt.month

# %%
#новый столбец для года
df['year_exposition'] = df['first_day_exposition'].dt.year

# %%
#напишем функцию категоризации по этажам
def floor_category(row):
    floors_total = row['floors_total']
    floor = row['floor']
    if floor == 1:
        return 'первый'
    elif floor == floors_total:
        return 'последний'
    elif 1 < floor < floors_total:
        return 'другой'

#категоризуем этажи с помощью функции  
df['floor_category'] = df.apply(floor_category, axis = 1)

# %%
#добавим столбец соотношения жилой площади к общей
df['living_area_proportion'] = df['living_area'] / df['total_area']

# %%
#добавим столбец отношения площади кухни к общей
df['kitchen_area_proportion'] = df['kitchen_area'] / df['total_area']

# %%
#Посмотрим информацию о всем датафрейме
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23539 entries, 0 to 23538
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   total_images             23538 non-null  float64
#  1   last_price               23538 non-null  float64
#  2   total_area               23538 non-null  float64
#  3   first_day_exposition     23538 non-null  datetime64[ns]
#  4   rooms                    23538 non-null  float64
#  5   ceiling_height           23538 non-null  float64
#  6   floors_total             23538 non-null  float64
#  7   living_area              23538 non-null  float64
#  8   floor                    23538 non-null  float64
#  9   is_apartment             23538 non-null  object
#  10  studio                   23538 non-null  object
#  11  open_plan                23538 non-null  object
#  12  kitchen_area             23392 non-null  float64
# ...

# %% [markdown]
# Новые столбцы добавлены.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# **1. Изучим следующие параметры: площадь, цена, число комнат, высота потолков. Построим гистограммы для каждого параметра.**

# %%
#общая площадь
df.plot(y = 'total_area', kind = 'hist', bins = 50, grid=True, figsize = (5,5), range = (0,500))
df['total_area'].describe()
# Out:
# count    23538.000000
# mean        60.336741
# std         35.670987
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.707500
# max        900.000000
# Name: total_area, dtype: float64

# %% [markdown]
# Распределение данных нормальное, есть выбросы но они не сильно влияют на данные

# %%
#цена
df.plot(y = 'last_price', kind = 'hist', bins = 100, grid=True, figsize = (5,5), range = (0,15000000))
df['last_price'].describe()
# Out:
# count    2.353800e+04
# mean     6.542895e+06
# std      1.091633e+07
# min      1.219000e+04
# 25%      3.406500e+06
# 50%      4.650000e+06
# 75%      6.799000e+06
# max      7.630000e+08
# Name: last_price, dtype: float64

# %% [markdown]
# С данными все в порядке

# %%
#изучим число комнат
df.plot(y = 'rooms', kind = 'hist', bins = 30, grid=True, figsize = (5,5))
df['rooms'].describe()
# Out:
# count    23538.000000
# mean         2.070907
# std          1.078841
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: rooms, dtype: float64

# %% [markdown]
# С данными все в порядке

# %%
#изучим высоту потолков
df.plot(y = 'ceiling_height', kind = 'hist', bins = 30, grid=True, figsize = (5,5), range = (2,5))
df['ceiling_height'].describe()
# Out:
# count    23538.000000
# mean         2.693685
# std          0.204093
# min          2.400000
# 25%          2.600000
# 50%          2.650000
# 75%          2.700000
# max          4.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# С данными все в порядке

# %% [markdown]
# **Вывод:**
#
# Общая площадь в нашей выборке колеблется от 12 до 900 м2, среднее значение 60, а медиана 52 м2. Распределение данных Гаусса.
#
# Цены на недвижимость имеют среднее значение в 6,5 млн руб., медиана 4,6 млн руб. Распределение данных Гаусса.
#
# Количество комнат колеблется от 1 до 19. Больше всего однокомнатных квартир.
#
# Высота потолков в среднем составляет 2,69 м, медиана 2,65 м.

# %% [markdown]
# **2. Изучим время продажи квартиры. Построим гистограмму. Посчитаем среднее и медиану. Определим, сколько обычно занимает продажа. Определим, когда можно считать, что продажи прошли очень быстро, а когда необычно долго.**

# %%
#отфильтруем данные от нулей и запишем их в новый датафрейм good_df
good_df = df.query('days_exposition != 0 and days_exposition.isna()==False')

#диаграмма размаха
plt.boxplot(good_df['days_exposition'])
plt.ylim(1,1000)

#гистограммы
good_df.plot(y = 'days_exposition', kind = 'hist', bins = 30, grid = True, range = (1,1600))
good_df.plot(y = 'days_exposition', kind = 'hist', bins = 100, grid = True, range = (1,200))

#среднее значение, медиана и межквартильный размах
good_df['days_exposition'].describe()
# Out:
# count    20371.000000
# mean       180.810711
# std        219.817314
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        231.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# **Вывод:**
# Можно считать, что при продаже квартиры в срок до 95 дней, что продажа прошла быстро, если же прошло более года дней, то продажа идет необычно долго

# %% [markdown]
# **3. Уберем редкие и выбивающиеся значения.**

# %%
#посмоттрим столбец rooms:
df['rooms'].unique()
# Out:
# array([ 3.,  1.,  2.,  4.,  5.,  6.,  0.,  7., 11.,  8., 14., 10., 15.,
#         9., 19., 16., 12., nan])

# %%
df['rooms'].value_counts()
# Out:
# 1.0     7993
# 2.0     7888
# 3.0     5772
# 4.0     1172
# 5.0      325
# 0.0      194
# 6.0      104
# 7.0       59
# 8.0       12
# 9.0        8
# 10.0       3
# 11.0       2
# 14.0       2
# 15.0       1
# 19.0       1
# 16.0       1
# 12.0       1
# Name: rooms, dtype: int64

# %% [markdown]
# Число комнат более 7 - довольно редкие значения, поэтому удалим эти строки

# %%
df = df.drop(np.where(df['rooms']>=8)[0])

# %%
#проверка
df['rooms'].value_counts()
# Out:
# 1.0    7993
# 2.0    7888
# 3.0    5772
# 4.0    1172
# 5.0     325
# 0.0     194
# 6.0     104
# 7.0      59
# Name: rooms, dtype: int64

# %%
#посмотрим столбец last_price
(df['last_price']/1000).describe()
# Out:
# count     23507.000000
# mean       6483.274599
# std       10433.132889
# min          12.190000
# 25%        3400.000000
# 50%        4630.000000
# 75%        6750.000000
# max      763000.000000
# Name: last_price, dtype: float64

# %%
df['last_price'].hist(bins=1000)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Проверим строки с ценой квартиры более 200 млн.

# %%
df[df['last_price']>=200000000]['last_price'].value_counts()
# Out:
# 330000000.0    1
# 230000000.0    1
# 763000000.0    1
# 240000000.0    1
# 401300000.0    1
# 300000000.0    1
# 245000000.0    1
# 289238400.0    1
# Name: last_price, dtype: int64

# %% [markdown]
# Удалим эти строки, так как стоимость квартиры более 200 млн. встречается редко

# %%
#удалим строки с помощью цикла
delete_price = df[df['last_price']>=200000000].index
drop_index_price=0
try:
    for drop_str in delete_price:
        df = df.drop(drop_str)
        drop_index_price+=1
except:
    print('Не удалось удалить строку')
print("Удалено строк: ", drop_index_price)
print("Всего осталось строк:", len(df))
# Out:
# Удалено строк:  8
# Всего осталось строк: 23500

# %%
#проверка
df[df['last_price']>=200000000]
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, city_centers_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition, non-living_area, price_per_square_meter, weekday_exposition, month_exposition, year_exposition, floor_category, living_area_proportion, kitchen_area_proportion]
# Index: []
#
# [0 rows x 30 columns]

# %%
#посмотрим столбец total_area:
df['total_area'].describe()
# Out:
# count    23499.000000
# mean        59.907056
# std         33.615933
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.500000
# max        631.200000
# Name: total_area, dtype: float64

# %%
df['total_area'].hist(bins=1000)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Удалим квартиры площадью до 20 и более 200 квадратных метров

# %%
df[df['total_area']<=20]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 710             5.0   1500000.0       17.00           2017-06-07    0.0
# 4055           10.0   3000000.0       20.00           2017-04-10    2.0
# 4516           12.0   3300000.0       18.00           2018-11-07    1.0
# 5280            3.0   1800000.0       20.00           2018-02-01    0.0
# 5817            3.0    945750.0       19.50           2017-09-18    0.0
# 6044            6.0    770000.0       18.00           2017-10-16    1.0
# 8405            7.0   2250000.0       19.00           2019-03-12    0.0
# 8678            9.0   2200000.0       18.40           2018-08-20    1.0
# 8704            1.0   1350000.0       18.80           2017-11-22    0.0
# 8822            6.0   2950000.0       20.00           2016-06-18    1.0
# 8835           10.0   2450000.0       15.50           2018-08-22    0.0
# 9104            0.0   3400000.0       17.60           2018-03-18    1.0
# ...

# %%
#удалим строки с помощью цикла
delete_area = df[df['total_area']<=20].index
drop_index_area=0
try:
    for drop_str in delete_area:
        df = df.drop(drop_str)
        drop_index_area+=1
except:
    print('Не удалось удалить строку')
print("Удалено строк: ", drop_index_area)
print("Всего осталось строк:", len(df))
# Out:
# Удалено строк:  35
# Всего осталось строк: 23465

# %%
#удалим строки с помощью цикла
delete_area2 = df[df['total_area']>=200].index
drop_index_area2=0
try:
    for drop_str in delete_area2:
        df = df.drop(drop_str)
        drop_index_area2+=1
except:
    print('Не удалось удалить строку')
print("Удалено строк: ", drop_index_area2)
print("Всего осталось строк:", len(df))
# Out:
# Удалено строк:  197
# Всего осталось строк: 23268

# %%
#проверка
df[df['total_area']<=20]
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, city_centers_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition, non-living_area, price_per_square_meter, weekday_exposition, month_exposition, year_exposition, floor_category, living_area_proportion, kitchen_area_proportion]
# Index: []
#
# [0 rows x 30 columns]

# %%
#проверка
df[df['total_area']>=200]
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, city_centers_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition, non-living_area, price_per_square_meter, weekday_exposition, month_exposition, year_exposition, floor_category, living_area_proportion, kitchen_area_proportion]
# Index: []
#
# [0 rows x 30 columns]

# %% [markdown]
# **Вывод:**
# - В столбце ceiling_height были аномально высокие значения и аномально низкие (например 1 м, что очень мало для высоты потолков), которые в пункте 2.0.6. были обработаны и приведены к адекватным значениям.
# - В столбце rooms удалили строки с числом комнат более 7.
# - В столбце last_price удалили квартиры с аномально высокой ценой
# - В столбце total_area удалили строки с площадью квартир менее 20 и более 200 квадратных метров.

# %% [markdown]
# **4. Какие факторы больше всего влияют на стоимость квартиры? Зависит ли цена от площади, числа комнат, удалённости от центра. Изучим зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучим зависимость от даты размещения: дня недели, месяца и года.**

# %% [markdown]
# - **Изучим зависимость цены квартиры от общей площади, числа комнат и удаленности от центра.**

# %%
#посмотрим на коэффициенты корреляции между ценой и площадью, числом комнат, удаленности от центра 
df[['total_area','rooms','city_centers_nearest','last_price']].corr()
# Out:
#                       total_area     rooms  city_centers_nearest  last_price
# total_area              1.000000  0.787109             -0.241749    0.715420
# rooms                   0.787109  1.000000             -0.165878    0.420799
# city_centers_nearest   -0.241749 -0.165878              1.000000   -0.302958
# last_price              0.715420  0.420799             -0.302958    1.000000

# %%
#построим матрицу диаграмм рассеяния
pd.plotting.scatter_matrix(df[["total_area",'rooms','city_centers_nearest','last_price']],figsize=(16,16))
# Out:
# array([[<AxesSubplot:xlabel='total_area', ylabel='total_area'>,
#         <AxesSubplot:xlabel='rooms', ylabel='total_area'>,
#         <AxesSubplot:xlabel='city_centers_nearest', ylabel='total_area'>,
#         <AxesSubplot:xlabel='last_price', ylabel='total_area'>],
#        [<AxesSubplot:xlabel='total_area', ylabel='rooms'>,
#         <AxesSubplot:xlabel='rooms', ylabel='rooms'>,
#         <AxesSubplot:xlabel='city_centers_nearest', ylabel='rooms'>,
#         <AxesSubplot:xlabel='last_price', ylabel='rooms'>],
#        [<AxesSubplot:xlabel='total_area', ylabel='city_centers_nearest'>,
#         <AxesSubplot:xlabel='rooms', ylabel='city_centers_nearest'>,
#         <AxesSubplot:xlabel='city_centers_nearest', ylabel='city_centers_nearest'>,
#         <AxesSubplot:xlabel='last_price', ylabel='city_centers_nearest'>],
#        [<AxesSubplot:xlabel='total_area', ylabel='last_price'>,
#         <AxesSubplot:xlabel='rooms', ylabel='last_price'>,
# ...

# %% [markdown]
# Цена больше зависит от общей площади, а не от количества комнат. Так же видно, что с ростом растояния до центра цена падает.

# %% [markdown]
# - **Изучим зависимость цены квартиры от этажа:**

# %%
df.groupby('floor_category')['last_price'].median().plot.bar()
# Out:
# <AxesSubplot:xlabel='floor_category'>

# %% [markdown]
# На последнем и первом этаже квартиры дешевле, чем на любом другом.

# %% [markdown]
# - **Изучим зависимость цены квартиры от дня недели размещения объявления.**

# %%
#добавим столбец со стоимостью в тысячах рублей для наглядности
df['last_price_thousand'] = df['last_price']/1000

# %%
pivot_table_weekday_exposition = df.pivot_table(index = 'weekday_exposition', values = 'last_price_thousand', aggfunc = ['mean', 'count', 'median'])
pivot_table_weekday_exposition.columns = ['mean', 'count', 'median']
pivot_table_weekday_exposition.plot(y = 'median')
pivot_table_weekday_exposition.sort_values('median', ascending = False)
# Out:
#                            mean  count    median
# weekday_exposition
# 1.0                 6012.776608   4125  4700.000
# 2.0                 5977.024128   3884  4661.705
# 0.0                 6063.490936   3554  4622.500
# 3.0                 6245.669233   4214  4600.000
# 4.0                 5850.725567   3937  4550.000
# 5.0                 5862.871309   1896  4500.000
# 6.0                 5758.740039   1657  4500.000

# %%
pivot_table_weekday_exposition.plot(kind='bar', label='weekday_exposition')
plt.title('Зависимость цены квартиры от дня недели')
# Out:
# Text(0.5, 1.0, 'Зависимость цены квартиры от дня недели')

# %% [markdown]
# Интересная информация получилась: чем ближе ко вторнику выставлены объявления, тем выше стоимость, хоть и незначительно. В объявлениях, выставленных в выходные, цена ниже.
#
# Возможно более обеспеченные граждане (соответсвенно с более дорогими квартирами) могут позволить себе выделить время (или имеют возможность делегировать это) выставить объявление в течение рабочей недели, тогда как менее обеспеченные люди в это время работают, а в  выходные выкладывают объявления.

# %% [markdown]
# - **Изучим зависимость цены квадратного метра от месяца размещения.**

# %%
pivot_table_month_exposition = df.pivot_table(index = 'month_exposition', values = 'last_price_thousand', aggfunc = ['mean', 'count', 'median'])
pivot_table_month_exposition.columns = ['mean', 'count', 'median']
pivot_table_month_exposition.plot(y = 'median')

pivot_table_month_exposition.sort_values('median', ascending = False)
# Out:
#                          mean  count  median
# month_exposition
# 4.0               5975.450914   2328  4780.0
# 11.0              6094.785743   2335  4680.0
# 9.0               6081.532769   1946  4675.0
# 12.0              6223.012830   1610  4650.0
# 2.0               6083.890936   2611  4630.0
# 3.0               5819.240713   2542  4605.0
# 1.0               6005.606658   1461  4600.0
# 7.0               6040.542821   1658  4600.0
# 8.0               6036.686387   1722  4550.0
# 10.0              5848.633636   2085  4550.0
# 5.0               5996.654178   1245  4500.0
# 6.0               5835.642169   1724  4400.0

# %%
pivot_table_month_exposition.plot(kind='bar', label='month_exposition')
plt.title('Зависимость цены квартиры от месяца')
# Out:
# Text(0.5, 1.0, 'Зависимость цены квартиры от месяца')

# %% [markdown]
# Самая высокая стоимость квардратного метра в апреле, сентябре и ноябре, а самая низкая стоимость в июне, августе и октябре.
#
# Как и во многих других областях нашей жизни, рынку недвижимости присущ сезонный характер. В данном случае видим, что в начале и в конце лета наименьшее предложение. Скорее всего многие в это время в отпусках и не могут заниматься продажей квартиры.

# %% [markdown]
# - **Изучим зависимость цены квадратного метра от года размещения.**

# %%
pivot_table_year_exposition = df.pivot_table(index = 'year_exposition', values = 'last_price_thousand', aggfunc = ['mean', 'count', 'median'])
pivot_table_year_exposition.columns = ['mean', 'count', 'median']
pivot_table_year_exposition.plot(y = 'median')
pivot_table_year_exposition.sort_values('median', ascending = False)
# Out:
#                          mean  count  median
# year_exposition
# 2014.0           10909.764090    133  7500.0
# 2015.0            7318.147915   1134  5234.5
# 2019.0            6369.123734   2842  5000.0
# 2018.0            5648.767920   8396  4550.0
# 2016.0            6106.670504   2707  4500.0
# 2017.0            5930.510792   8055  4500.0

# %%
pivot_table_year_exposition.plot(kind='bar', label='year_exposition')
plt.title('Зависимость цены квартиры от года')
# Out:
# Text(0.5, 1.0, 'Зависимость цены квартиры от года')

# %% [markdown]
# C 2014 до 2016 года цена снижалась, причем с 2014 по 2015 довольно резко. Скорее всего это связано с валютным кризисом в России в эти годы. Вот что нашлось по этому поводу в Википедии:
#
# *Валютный кризис в России (2014—2015) — резкое ослабление российского рубля по отношению к иностранным валютам, вызванное стремительным снижением мировых цен на нефть, от экспорта которой во многом зависит доходная часть бюджета России, а также введением экономических санкций в отношении России в связи с аннексией Крыма и вооруженным конфликтом на востоке Украины.*

# %% [markdown]
# **5. Определим 10 населённых пунктов с наибольшим числом объявлений. Посчитаем среднюю цену квадратного метра в этих населённых пунктах. Выделим населённые пункты с самой высокой и низкой стоимостью жилья.**

# %%
locality_pivot_table = df.pivot_table(index = 'locality_name', values = 'price_per_square_meter', aggfunc=['count', 'mean'])
locality_pivot_table.columns = ['count', 'mean']
locality_pivot_table = locality_pivot_table.sort_values('count', ascending = False).head(10)
locality_pivot_table
# Out:
#                    count           mean
# locality_name
# Санкт-Петербург    15395  113300.338880
# поселок Мурино       551   85626.174029
# поселок Шушары       438   78529.235183
# Всеволожск           396   68747.651995
# Пушкин               363  103077.242287
# Колпино              337   75333.295816
# поселок Парголово    326   90332.262638
# Гатчина              307   68746.146515
# деревня Кудрово      298   92481.848054
# Выборг               235   58238.143277

# %%
#максимальная стоимость
locality_pivot_table[locality_pivot_table['mean']==locality_pivot_table['mean'].max()]
# Out:
#                  count          mean
# locality_name
# Санкт-Петербург  15395  113300.33888

# %%
#минимальная стоимость
locality_pivot_table[locality_pivot_table['mean']==locality_pivot_table['mean'].min()]
# Out:
#                count          mean
# locality_name
# Выборг           235  58238.143277

# %% [markdown]
# Наиболее высокая стоимость квадратного метра в Санкт-Петербурге, тогда как самая низкая в Выборге.

# %% [markdown]
# **6. Выделим квартиры в Санкт-Петербурге (locality_name). Выясним, какая область входит в центр. **

# %%
df['city_centers_nearest'].isna().sum()
# Out:
# 5474

# %%
# Создадим столбец с расстоянием до центра в километрах и построим график
df['city_centers_nearest_km'] = df['city_centers_nearest']/1000
df['city_centers_nearest_km'] = df['city_centers_nearest_km'].dropna().astype('int')
pivot_table_km = df.query('locality_name == "Санкт-Петербург"').pivot_table(index = 'city_centers_nearest_km', values = 'price_per_square_meter', aggfunc = 'mean')
pivot_table_km.plot()
pivot_table_km
# Out:
#                          price_per_square_meter
# city_centers_nearest_km
# 0.0                               169191.009870
# 1.0                               146503.166313
# 2.0                               138332.141228
# 3.0                               122880.077941
# 4.0                               135390.100807
# 5.0                               143715.367559
# 6.0                               149794.196813
# 7.0                               138837.461620
# 8.0                               119670.095514
# 9.0                               110130.810833
# 10.0                              111452.726611
# 11.0                              106598.581022
# 12.0                              108336.567336
# 13.0                              107159.991901
# 14.0                              105023.386033
# 15.0                              101899.884450
# 16.0                              100109.236521
# 17.0                               94694.621115
# ...

# %% [markdown]
# Центром можно считать радиус в пределах 5-8 км.

# %% [markdown]
# **7. Проанализируем квартиры в центрке и изучим следующие параметры: площадь, цена, число комнат, высота потолков. Также выделим факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления).**

# %%
#выделим квартиры в центре, беря за радиус 8 км
center_spb_df = df.query('city_centers_nearest_km <= 8 and locality_name == "Санкт-Петербург"').dropna()

# %% [markdown]
# - **Зависимость стоимости квартиры в центре от количества комнат.**

# %%
center_spb_rooms = center_spb_df.pivot_table(index = 'rooms', values = 'last_price_thousand', aggfunc = ['mean', 'count', 'median'])
center_spb_rooms.columns = ['mean', 'count', 'median']
center_spb_rooms.plot(y = 'median')
#коэффициент корреляции
center_spb_df['rooms'].corr(center_spb_df['last_price'])
# Out:
# 0.35062803424959693

# %%
center_spb_rooms.sort_values('median', ascending = False)
# Out:
#                mean  count      median
# rooms
# 7.0    18682.000000     20  16750.0000
# 6.0    17648.750000     48  14000.0000
# 5.0    17172.328739    176  13350.0000
# 4.0    16226.935925    519  11999.0000
# 3.0    13317.786812   1333   9830.0000
# 2.0     9013.531217   1335   7500.0000
# 1.0     6257.112994    718   5682.1105
# 0.0     3702.500000      4   3440.0000

# %%
center_spb_rooms = center_spb_df.pivot_table(index = 'rooms', values = 'last_price_thousand', aggfunc = ['mean', 'count', 'median'])
center_spb_rooms.plot(kind='bar', label='rooms')
plt.legend()
plt.title('Зависимость стоимости квартиры от количества комнат')
# Out:
# Text(0.5, 1.0, 'Зависимость стоимости квартиры от количества комнат')

# %% [markdown]
# В центре, чем больше комнат, тем дороже стоимость квартиры, что логично, так как с увеличением числа квартир как правило растет и площадь квартиры.

# %% [markdown]
# - **Зависимость стоимости квартиры в центре от этажа.**

# %%
center_spb_df.groupby('floor_category')['last_price_thousand'].median().plot.bar()
# Out:
# <AxesSubplot:xlabel='floor_category'>

# %% [markdown]
# В центре Санкт-Петербурга на первом этаже квартиры дешевле, чем на последнем или любом другом. Скорее всего это связано с тем, что первые этажи находятся близко к тротуарам, к дорогам или каким-то помещениям коммерческого типа, поэтому на первом этаже в центре Питера менее комфортно жить.

# %% [markdown]
# - **Зависимость стоимости квартиры в центре от удаленности от центра.**

# %%
center_spb_df.plot(kind = 'scatter', y = 'last_price', x = 'city_centers_nearest', alpha = 0.3)
center_spb_df['city_centers_nearest'].corr(center_spb_df['last_price_thousand'])
# Out:
# -0.10793442671781853

# %% [markdown]
# Коэффициент корреляции довольно небольшой, в большом городе в центре в принципе достаточно дорогое жилье.

# %% [markdown]
# - **Зависимость стоимости квартиры в центре от дня недели размещения объявления.**

# %%
center_spb_weekday_exposition = center_spb_df.pivot_table(index = 'weekday_exposition', values = 'last_price_thousand', aggfunc = ['mean', 'count', 'median'])
center_spb_weekday_exposition.columns = ['mean', 'count', 'median']
center_spb_weekday_exposition.plot(y = 'median')
center_spb_weekday_exposition.sort_values('median', ascending = False)
# Out:
#                             mean  count  median
# weekday_exposition
# 0.0                 11752.742651    634  8900.0
# 6.0                 11464.273144    243  8800.0
# 2.0                 10923.254491    702  8550.0
# 3.0                 11788.089802    849  8500.0
# 4.0                 10921.978551    700  8500.0
# 1.0                 11076.581209    717  8300.0
# 5.0                 11225.379565    308  7950.0

# %%
center_spb_weekday_exposition = center_spb_df.pivot_table(index = 'weekday_exposition', values = 'last_price_thousand', aggfunc = ['mean', 'count', 'median'])
center_spb_weekday_exposition.plot(kind='bar', label='weekday_exposition')
plt.legend()
plt.title('Зависимость стоимости квартиры от дня недели')
# Out:
# Text(0.5, 1.0, 'Зависимость стоимости квартиры от дня недели')

# %% [markdown]
# Cитуация не отличается от всей выборки: минимальные цены во вторник и субботу.

# %% [markdown]
# - **Зависимость стоимости квартиры в центре от месяца размещения объявления.**

# %%
center_spb_month_exposition = center_spb_df.pivot_table(index = 'month_exposition', values = 'last_price_thousand', aggfunc = ['mean', 'count', 'median'])
center_spb_month_exposition.columns = ['mean', 'count', 'median']
center_spb_month_exposition.plot(y = 'median')

center_spb_month_exposition.sort_values('median', ascending = False)
# Out:
#                           mean  count     median
# month_exposition
# 9.0               11075.538532    372  8995.0000
# 11.0              11597.521622    410  8900.0000
# 7.0               11594.925843    325  8787.8190
# 8.0               11418.963151    311  8548.0000
# 1.0               11383.493723    253  8500.0000
# 2.0               12044.142731    442  8500.0000
# 3.0               10837.044828    448  8500.0000
# 5.0               11048.586187    246  8417.5255
# 6.0               11424.510799    324  8325.0000
# 10.0              10753.448645    358  8299.5000
# 4.0               10789.038079    390  8245.0000
# 12.0              11780.160007    274  7550.0000

# %%
center_spb_month_exposition = center_spb_df.pivot_table(index = 'month_exposition', values = 'last_price_thousand', aggfunc = ['mean', 'count', 'median'])
center_spb_month_exposition.plot(kind='bar', label='month_exposition')
plt.legend()
plt.title('Зависимость стоимости квартиры от месяца')
# Out:
# Text(0.5, 1.0, 'Зависимость стоимости квартиры от месяца')

# %% [markdown]
# Здесь ситуация почти как во всей выборке: наиболее высокие центы предлагаются в январь, июль, сентябрь и ноябрь, а наименее - апрель, июнь, август, октябрь и декабрь.

# %% [markdown]
# - **Зависимость стоимости квартиры в центре от года размещения объявления.**

# %%
center_spb_year_exposition = center_spb_df.pivot_table(index = 'year_exposition', values = 'last_price_thousand', aggfunc = ['mean', 'count', 'median'])
center_spb_year_exposition.columns = ['mean', 'count', 'median']
center_spb_year_exposition.query('count > 50').plot(y = 'median')

center_spb_year_exposition.query('count > 50').sort_values('median', ascending = False)
# Out:
#                          mean  count  median
# year_exposition
# 2015.0           12569.142493    341  9000.0
# 2016.0           11751.940523    560  8825.0
# 2019.0           12125.312559    465  8635.0
# 2017.0           11296.622268   1466  8452.5
# 2018.0           10290.775138   1286  8300.0

# %%
center_spb_year_exposition = center_spb_df.pivot_table(index = 'year_exposition', values = 'last_price_thousand', aggfunc = ['mean', 'count', 'median'])
center_spb_year_exposition.plot(kind='bar', label='year_exposition')
plt.legend()
plt.title('Зависимость стоимости квартиры от года')
# Out:
# Text(0.5, 1.0, 'Зависимость стоимости квартиры от года')

# %% [markdown]
#  В Питере аналогично всей выборке в 2014-2015 годах цены падали, но падение наблюдалось вплоть до 2018 года, при этом во всей выборке в 2016-2018 годах падение цен было более плавным. Связяно это все с той же причиной.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# В результате обработки входных данных были устранены дубликаты, исправлены пропуски в данных, которые потребовались для последующей аналитической обработки этих данных.
# Исходя их проделанного анализа определили от чего зависит стоимость квадратного метра по всей выборке и конкретно в Санкт-Петербурге.
#
# В ходе проделанной работы определили, что то на стоимость квадратного метра квартиры больше всего влияют количество комнат, этаж квартиры, близость к центру. При этом на стоимость может повлиять и день недели, в который выкладывается объявление на продажу.
# Также обнаружили, что в 2014-2015 годах цены на недвижимость значительно упали (по понятным причинам), но затем в 2016 году стремительно начали расти.
# Нужно выделить еще то, что в Яндекс.Недвижимости автоматически могут сниматься объявления в связи с истечением срока объявления, что тоже было учтено в ходе анализа.
#
# В центре Питера стоимость квартиры больше зависит от количества комнат, нежели во всей выборке. При этом дата выставления объявления квартиры в центре Питера и во всей выборке влияет одинаково на стоимость квартиры.
